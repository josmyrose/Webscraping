# %% [markdown]
# <a href="https://colab.research.google.com/github/josmyrose/Webscraping/blob/main/Spam_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **The business context**
#
# The ABC company recieves several messages over their company mail id.They want to classify whether the messages are spam or not.
#
# The company appointed an analyst to develop a model for classifying the message as spam or not.

# %% [markdown]
# Import necessary libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import nltk
from nltk import word_tokenize # for tokenizing
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')
from imblearn.over_sampling import RandomOverSampler
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score


from sklearn.feature_extraction.text import TfidfVectorizer
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# **Reading and analysing the dataset**

# %%
df=pd.read_csv("/content/drive/MyDrive/spam_classification", sep="\t",header=None)

# %%
df.head()
# Out:
#       0                                                  1
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# Renaming the dataset columns

# %%
df.rename(columns={0: 'label', 1: 'text'}, inplace=True)

# %%
print("The size of the dataset",df.shape)
print("The Datatype of columns\n {} of the dataset\n".format(df.dtypes))
print("values of different categories\n",df['label'].value_counts())#for getting the count of each item in the product table.We can understand that the product column has five types of values.
print("Number of null values in the dataset\n",df.isnull().sum())
# Out:
# The size of the dataset (5572, 2)
# The Datatype of columns
#  label    object
# text     object
# dtype: object of the dataset
#
# values of different categories
#  ham     4825
# spam     747
# Name: label, dtype: int64
# Number of null values in the dataset
#  label    0
# text     0
# dtype: int64

# %% [markdown]
# From the above result,we can understand that dataset is imbalanced(ham      4825,
# spam     747)
# To balance the dataset,use random

# %% [markdown]
# **Calculate the length of each data sample**
# Add a column to the dataset,to get the length of text in the dataset

# %%
word_l=[]
for x in df['text']:
  word_l.append(len(x))

# %%
df['word_l']=word_l

# %%
df.head()
# Out:
#   label                                               text  word_l
# 0   ham  Go until jurong point, crazy.. Available only ...     111
# 1   ham                      Ok lar... Joking wif u oni...      29
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...     155
# 3   ham  U dun say so early hor... U c already then say...      49
# 4   ham  Nah I don't think he goes to usf, he lives aro...      61

# %% [markdown]
# **TEXT CLEANING**

# %%
#Another way to find the length of text 
df['word_l']=df['text'].apply(lambda x: len(x))

# %%
df.head()
# Out:
#   label                                               text  word_l
# 0   ham  Go until jurong point, crazy.. Available only ...     111
# 1   ham                      Ok lar... Joking wif u oni...      29
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...     155
# 3   ham  U dun say so early hor... U c already then say...      49
# 4   ham  Nah I don't think he goes to usf, he lives aro...      61

# %% [markdown]
# **Text Cleaning steps:**
#
#
# 1.Make the text lowercase. As you probably know, NLP is case-sensitive.
# 2.	Remove line breaks. Again, depending on your source, you might have encoded line breaks.
# 3.	Remove punctuation. This is using the string library. Other punctuation can be added as needed.
# 4.	Remove stop words using the NLTK library. There is a list in the next line to add additional stop words to the function as needed. These might be noisy domain words or anything else that makes the contextless clear.
# 5.	Removing numbers. Optional depending on your data.
# 6.	Stemming or Lemmatization. This process is an argument in the function. You can choose either one via with Stem or Lem. The default is to use none.

# %% [markdown]
# It includes removing unnecessary words, punctuation, stop words, white spaces, and unnecessary symbols from the text dataset.

# %%
#Make the text lowercase
def lower_case(text): #user defined function for converting upper case text to lower case
  return text.lower()

# %%
df['text']=df['text'].apply(lambda x: lower_case(x))

# %%
df.head(5)
# Out:
#   label                                               text  word_l
# 0   ham  go until jurong point, crazy.. available only ...     111
# 1   ham                      ok lar... joking wif u oni...      29
# 2  spam  free entry in 2 a wkly comp to win fa cup fina...     155
# 3   ham  u dun say so early hor... u c already then say...      49
# 4   ham  nah i don't think he goes to usf, he lives aro...      61

# %%
# Remove punctuation

def remove_punctuation(text):
    return text.translate(str.maketrans('', ''))

# %%
df['text'] = df['text'].apply(lambda x: remove_punctuation(x))

# %% [markdown]
# Stopwords
#
#
# Stopwords are commonly used words that are usually filtered out in natural language processing (NLP) tasks because they do not add much meaning to the text. Examples of stopwords include "a", "an", "the", "and", "or", "in", "on", "at", "is", "are", "was", "were", etc.
#
# Removing stopwords can help in reducing the dimensionality of the text data and improving the efficiency and accuracy of NLP models. This is because the presence or absence of stopwords is often not very informative in determining the sentiment, topic, or intent of the text.
#
# There are several ways to remove stopwords in NLP tasks. One way is to use pre-defined lists of stopwords that are available in popular NLP libraries such as NLTK, spaCy, and scikit-learn. These lists can be customized by adding or removing stopwords as per the specific use case.

# %%
label_map = {
    'ham': 0,
    'spam': 1,
}

# %%
df['label'] = df['label'].map(label_map)

# %%
#Remove stopwords
def remove_stopwords(text):
  stop_words = set(stopwords.words('english'))
  removed=[]
  tokens = word_tokenize(text)
  print("\nTokens {} in text {}".format(tokens,text))
  for i in range(len(tokens)):
    if tokens[i] not in stop_words:
      removed.append(tokens[i])
    return " ".join(removed)

# %%
df['text'] = df['text'].apply(lambda x: remove_stopwords(x))
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Tokens ['ok', 'lor', '...', 'but', 'buy', 'wat', '?'] in text ok lor... but buy wat?
#
# Tokens ['somebody', 'should', 'go', 'to', 'andros', 'and', 'steal', 'ice'] in text somebody should go to andros and steal ice
#
# Tokens ['don', 'know', '.', 'i', "did't", 'msg', 'him', 'recently', '.'] in text don know. i did't msg him recently.
#
# Tokens ['take', 'us', 'out', 'shopping', 'and', 'mark', 'will', 'distract', 'isaiah.=d'] in text take us out shopping and mark will distract isaiah.=d
#
# Tokens ['mum', ',', 'hope', 'you', 'are', 'having', 'a', 'great', 'day', '.', 'hoping', 'this', 'text', 'meets', 'you', 'well', 'and', 'full', 'of', 'life', '.', 'have', 'a', 'great', 'day', '.', 'abiola'] in text mum, hope you are having a great day. hoping this text meets you well and full of life. have a great day. abiola
#
# Tokens ['there', 'is', 'no', 'sense', 'in', 'my', 'foot', 'and', 'penis', '.'] in text there is no sense in my foot and penis.
#
# Tokens ['okay', 'but', 'i', 'thought', 'you', 'were', 'the', 'expert'] in text okay but i thought you were the expert
#
# Tokens ['*', 'deep', 'sigh', '*', '...', 'i', 'miss', 'you', ':', '-', '(', '...', 'i', 'am', 'really', 'surprised', 'you', 'have', "n't", 'gone', 'to', 'the', 'net', 'cafe', 'yet', 'to', 'get', 'to', 'me', '...', 'do', "n't", 'you', 'miss', 'me', '?'] in text *deep sigh* ... i miss you :-( ... i am really surprised you haven't gone to the net cafe yet to get to me ... don't you miss me?
#
# Tokens ['s.s', ':', ')', 'i', 'thinl', 'role', 'is', 'like', 'sachin.just', 'standing', '.', 'others', 'have', 'to', 'hit', '.'] in text s.s:)i thinl role is like sachin.just standing. others have to hit.
#
# Tokens ['have', 'a', 'great', 'trip', 'to', 'india', '.', 'and', 'bring', 'the', 'light', 'to', 'everyone', 'not', 'just', 'with', 'the', 'project', 'but', 'with', 'everyone', 'that', 'is', 'lucky', 'to', 'see', 'you', 'smile', '.', 'bye', '.', 'abiola'] in text have a great trip to india. and bring the light to everyone not just with the project but with everyone that is lucky to see you smile. bye. abiola
#
# Tokens ['and', 'very', 'importantly', ',', 'all', 'we', 'discuss', 'is', 'between', 'u', 'and', 'i', 'only', '.'] in text and very importantly, all we discuss is between u and i only.
#
# Tokens ['k', '..', 'k', ':', ')', 'how', 'about', 'your', 'training', 'process', '?'] in text k..k:)how about your training process?
#
# Tokens ['ok', 'lor', '.', 'i', 'ned', '2', 'go', 'toa', 'payoh', '4', 'a', 'while', '2', 'return', 'smth', 'u', 'wan', '2', 'send', 'me', 'there', 'or', 'wat', '?'] in text ok lor. i ned 2 go toa payoh 4 a while 2 return smth u wan 2 send me there or wat?
#
# Tokens ['in', 'da', 'car', 'park'] in text in da car park
#
# Tokens ['i', 'wish', 'that', 'i', 'was', 'with', 'you', '.', 'holding', 'you', 'tightly', '.', 'making', 'you', 'see', 'how', 'important', 'you', 'are', '.', 'how', 'much', 'you', 'mean', 'to', 'me', '...', 'how', 'much', 'i', 'need', 'you', '...', 'in', 'my', 'life', '...'] in text i wish that i was with you. holding you tightly. making you see how important you are. how much you mean to me ... how much i need you ... in my life ...
#
# Tokens ['so', 'i', 'asked', 'how', "'s", 'anthony', '.', 'dad', '.', 'and', 'your', 'bf'] in text so i asked how's anthony. dad. and your bf
#
# Tokens ["'wnevr", 'i', 'wana', 'fal', 'in', 'luv', 'vth', 'my', 'books', ',', 'my', 'bed', 'fals', 'in', 'luv', 'vth', 'me', '..', '!', "''", '.', 'yen', 'madodu', ',', 'nav', 'pretsorginta', ',', 'nammanna', 'pretsovru', 'important', 'alwa', '....', '!', '!', ':', ')', 'gud', 'eveb-', ')', '.'] in text 'wnevr i wana fal in luv vth my books, my bed fals in luv vth me..!'' . yen madodu, nav pretsorginta, nammanna pretsovru important alwa....!!:) gud eveb-).
#
# Tokens ['what', 'today-sunday', '..', 'sunday', 'is', 'holiday', '..', 'so', 'no', 'work', '..'] in text what today-sunday..sunday is holiday..so no work..
#
# Tokens ['am', 'going', 'to', 'take', 'bath', 'ill', 'place', 'the', 'key', 'in', 'window', ':', '-', ')'] in text am going to take bath ill place the key in window:-)
#
# Tokens ['lord', 'of', 'the', 'rings', ':', 'return', 'of', 'the', 'king', 'in', 'store', 'now', '!', 'reply', 'lotr', 'by', '2', 'june', '4', 'chance', '2', 'win', 'lotr', 'soundtrack', 'cds', 'stdtxtrate', '.', 'reply', 'stop', 'to', 'end', 'txts'] in text lord of the rings:return of the king in store now!reply lotr by 2 june 4 chance 2 win lotr soundtrack cds stdtxtrate. reply stop to end txts
#
# Tokens ['dear', ',', 'take', 'care', '.', 'i', 'am', 'just', 'reaching', 'home.love', 'u', 'a', 'lot', '.'] in text dear, take care. i am just reaching home.love u a lot.
#
# Tokens ['staff.science.nus.edu.sg/~phyhcmk/teaching/pc1323'] in text staff.science.nus.edu.sg/~phyhcmk/teaching/pc1323
#
# Tokens ['have', 'you', 'emigrated', 'or', 'something', '?', 'ok', 'maybe', '5.30', 'was', 'a', 'bit', 'hopeful', '...'] in text have you emigrated or something? ok maybe 5.30 was a bit hopeful...
#
# Tokens ['olol', 'i', 'printed', 'out', 'a', 'forum', 'post', 'by', 'a', 'guy', 'with', 'the', 'exact', 'same', 'prob', 'which', 'was', 'fixed', 'with', 'a', 'gpu', 'replacement', '.', 'hopefully', 'they', 'dont', 'ignore', 'that', '.'] in text olol i printed out a forum post by a guy with the exact same  prob which was fixed with a gpu replacement. hopefully they dont ignore that.
#
# Tokens ['we', 'walked', 'from', 'my', 'moms', '.', 'right', 'on', 'stagwood', 'pass', 'right', 'on', 'winterstone', 'left', 'on', 'victors', 'hill', '.', 'address', 'is', '&', 'lt', ';', '#', '&', 'gt', ';'] in text we walked from my moms. right on stagwood pass right on winterstone left on victors hill. address is &lt;#&gt;
#
# Tokens ['yo', ',', 'you', 'at', 'jp', 'and', 'hungry', 'like', 'a', 'mofo', '?'] in text yo, you at jp and hungry like a mofo?
#
# Tokens ['this', 'is', 'all', 'just', 'creepy', 'and', 'crazy', 'to', 'me', '.'] in text this is all just creepy and crazy to me.
#
# Tokens ['ok', '...', 'i', 'din', 'get', 'ur', 'msg', '...'] in text ok... i din get ur msg...
#
# Tokens ['tessy', '..', 'pls', 'do', 'me', 'a', 'favor', '.', 'pls', 'convey', 'my', 'birthday', 'wishes', 'to', 'nimya', '..', 'pls', 'dnt', 'forget', 'it', '.', 'today', 'is', 'her', 'birthday', 'shijas'] in text tessy..pls do me a favor. pls convey my birthday wishes to nimya..pls dnt forget it. today is her birthday shijas
#
# Tokens ['pathaya', 'enketa', 'maraikara', 'pa', "'"] in text pathaya enketa maraikara pa'
#
# Tokens ['even', 'if', 'he', 'my', 'friend', 'he', 'is', 'a', 'priest', 'call', 'him', 'now'] in text even if he my friend he is a priest call him now
#
# Tokens ['u', 'so', 'lousy', ',', 'run', 'already', 'come', 'back', 'then', 'half', 'dead', '...', 'hee', '...'] in text u so lousy, run already come back then half dead... hee...
#
# Tokens ['that', "'s", 'y', 'i', 'said', 'it', "'s", 'bad', 'dat', 'all', 'e', 'gals', 'know', 'u', '...', 'wat', 'u', 'doing', 'now', '?'] in text that's y i said it's bad dat all e gals know u... wat u doing now?
#
# Tokens ['or', 'remind', 'me', 'in', 'a', 'few', 'hrs', '.'] in text or remind me in a few hrs.
#
# Tokens ['i', 'had', 'been', 'hoping', 'i', 'would', 'not', 'have', 'to', 'send', 'you', 'this', 'message', '.', 'my', 'rent', 'is', 'due', 'and', 'i', 'dont', 'have', 'enough', 'for', 'it', '.', 'my', 'reserves', 'are', 'completely', 'gone', '.', 'its', 'a', 'loan', 'i', 'need', 'and', 'was', 'hoping', 'you', 'could', 'her', '.', 'the', 'balance', 'is', '&', 'lt', ';', '#', '&', 'gt', ';', '.', 'is', 'there', 'a', 'way', 'i', 'could', 'get', 'that', 'from', 'you', ',', 'till', 'mid', 'march', 'when', 'i', 'hope', 'to', 'pay', 'back', '.'] in text i had been hoping i would not have to send you this message. my rent is due and i dont have enough for it. my reserves are completely gone. its a loan i need and was hoping you could her. the balance is  &lt;#&gt; . is there a way i could get that from you, till mid march when i hope to pay back.
#
# Tokens ['hi', '.', 'happy', 'new', 'year', '.', 'i', 'dont', 'mean', 'to', 'intrude', 'but', 'can', 'you', 'pls', 'let', 'me', 'know', 'how', 'much', 'tuition', 'you', 'paid', 'last', 'semester', 'and', 'how', 'much', 'this', 'semester', 'is', '.', 'thanks'] in text hi. happy new year. i dont mean to intrude but can you pls let me know how much tuition you paid last semester and how much this semester is. thanks
#
# Tokens ['hello', 'hun', 'how', 'ru', '?', 'its', 'here', 'by', 'the', 'way', '.', 'im', 'good', '.', 'been', 'on', '2', 'dates', 'with', 'that', 'guy', 'i', 'met', 'in', 'walkabout', 'so', 'far', '.', 'we', 'have', 'to', 'meet', 'up', 'soon', '.', 'hows', 'everyone', 'else', '?'] in text hello hun how ru? its here by the way. im good. been on 2 dates with that guy i met in walkabout so far. we have to meet up soon. hows everyone else?
#
# Tokens ['lol', 'i', 'was', 'gon', 'na', 'last', 'month', '.', 'i', 'cashed', 'some', 'in', 'but', 'i', 'left', '&', 'lt', ';', '#', '&', 'gt', ';', 'just', 'in', 'case', '.', 'i', 'was', 'collecting', 'more', 'during', 'the', 'week', 'cause', 'they', 'announced', 'it', 'on', 'the', 'blog', '.'] in text lol i was gonna last month. i cashed some in but i left &lt;#&gt; just in case. i was collecting more during the week cause they announced it on the blog.
#
# Tokens ['good', 'luck', '!', 'draw', 'takes', 'place', '28th', 'feb', '06.', 'good', 'luck', '!', 'for', 'removal', 'send', 'stop', 'to', '87239', 'customer', 'services', '08708034412'] in text good luck! draw takes place 28th feb 06. good luck! for removal send stop to 87239 customer services 08708034412
#
# Tokens ['short', 'but', 'cute', ':', '``', 'be', 'a', 'good', 'person', ',', 'but', 'dont', 'try', 'to', 'prove', "''", '.....', 'gud', 'mrng', '...'] in text short but cute : " be a good person , but dont try to prove" ..... gud mrng...
#
# Tokens ['just', 'have', "n't", 'decided', 'where', 'yet', 'eh', '?'] in text just haven't decided where yet eh ?
#
# Tokens ['wat', 'time', 'liao', ',', 'where', 'still', 'got', '.'] in text wat time liao, where still got.
#
# Tokens ['yes', 'watching', 'footie', 'but', 'worried', 'we', "'re", 'going', 'to', 'blow', 'it', '-', 'phil', 'neville', '?'] in text yes watching footie but worried we're going to blow it - phil neville?
#
# Tokens ['i', 'wait', '4', 'ü', 'inside', 'da', 'car', 'park', '...'] in text i wait 4 ü inside da car park...
#
# Tokens ['uncle', 'abbey', '!', 'happy', 'new', 'year', '.', 'abiola'] in text uncle abbey! happy new year. abiola
#
# Tokens ['now', 'am', 'free', 'call', 'me', 'pa', '.'] in text now am free call me pa.
#
# Tokens ['r', 'u', 'saying', 'i', 'should', 're', 'order', 'the', 'slippers', 'cos', 'i', 'had', 'to', 'pay', 'for', 'returning', 'it', '.'] in text r u saying i should re order the slippers cos i had to pay for returning it.
#
# Tokens ['stop', 'knowing', 'me', 'so', 'well', '!'] in text stop knowing me so well!
#
# Tokens ['good', 'evening', '!', 'this', 'is', 'roger', '.', 'how', 'are', 'you', '?'] in text good evening! this is roger. how are you?
#
# Tokens ['small', 'problem', 'in', 'auction', ':', ')', 'punj', 'now', 'asking', 'tiwary'] in text small problem in auction:)punj now asking tiwary
#
# Tokens ['free', 'entry', 'in', '2', 'a', 'weekly', 'comp', 'for', 'a', 'chance', 'to', 'win', 'an', 'ipod', '.', 'txt', 'pod', 'to', '80182', 'to', 'get', 'entry', '(', 'std', 'txt', 'rate', ')', 't', '&', 'c', "'s", 'apply', '08452810073', 'for', 'details', '18+'] in text free entry in 2 a weekly comp for a chance to win an ipod. txt pod to 80182 to get entry (std txt rate) t&c's apply 08452810073 for details 18+
#
# Tokens ['he', 'telling', 'not', 'to', 'tell', 'any', 'one', '.', 'if', 'so', 'treat', 'for', 'me', 'hi', 'hi', 'hi'] in text he telling not to tell any one. if so treat for me hi hi hi
#
# Tokens ['my', 'uncles', 'in', 'atlanta', '.', 'wish', 'you', 'guys', 'a', 'great', 'semester', '.'] in text my uncles in atlanta. wish you guys a great semester.
#
# Tokens ['1st', 'wk', 'free', '!', 'gr8', 'tones', 'str8', '2', 'u', 'each', 'wk', '.', 'txt', 'nokia', 'on', 'to', '8007', 'for', 'classic', 'nokia', 'tones', 'or', 'hit', 'on', 'to', '8007', 'for', 'polys', '.', 'nokia/150p', 'poly/200p', '16+'] in text 1st wk free! gr8 tones str8 2 u each wk. txt nokia on to 8007 for classic nokia tones or hit on to 8007 for polys. nokia/150p poly/200p 16+
#
# Tokens ['u', 'coming', '2', 'pick', 'me', '?'] in text u coming 2 pick me?
#
# Tokens ['thats', 'cool', '.', 'i', 'liked', 'your', 'photos', '.', 'you', 'are', 'very', 'sexy', '!'] in text thats cool. i liked your photos. you are very sexy!
#
# Tokens ['would', 'u', 'fuckin', 'believe', 'it', 'they', 'didnt', 'know', 'i', 'had', 'thurs', 'pre', 'booked', 'off', 'so', 'they', 're', 'cancelled', 'me', 'again', '!', 'that', 'needs', 'to', 'b', 'sacked'] in text would u fuckin believe it they didnt know i had thurs pre booked off so they re cancelled me again! that needs to b sacked
#
# Tokens ['haha', 'better', 'late', 'than', 'ever', ',', 'any', 'way', 'i', 'could', 'swing', 'by', '?'] in text haha better late than ever, any way i could swing by?
#
# Tokens ['ok.', 'but', 'i', 'finish', 'at', '6', '.'] in text ok. but i finish at 6.
#
# Tokens ['lookatme', '!', ':', 'thanks', 'for', 'your', 'purchase', 'of', 'a', 'video', 'clip', 'from', 'lookatme', '!', ',', 'you', "'ve", 'been', 'charged', '35p', '.', 'think', 'you', 'can', 'do', 'better', '?', 'why', 'not', 'send', 'a', 'video', 'in', 'a', 'mmsto', '32323', '.'] in text lookatme!: thanks for your purchase of a video clip from lookatme!, you've been charged 35p. think you can do better? why not send a video in a mmsto 32323.
#
# Tokens ['i', "'ve", 'been', 'barred', 'from', 'all', 'b', 'and', 'q', 'stores', 'for', 'life', '!', '?', 'this', 'twat', 'in', 'orange', 'dungerees', 'came', 'up', 'to', 'me', 'and', 'asked', 'if', 'i', 'wanted', 'decking', '?', 'so', 'i', 'got', 'the', 'first', 'punch', 'in', '!', '!'] in text i've been barred from all b and q stores for life!?this twat in orange dungerees came up to me and asked if i wanted decking? so i got the first punch in!!
#
# Tokens ['so', 'no', 'messages', '.', 'had', 'food', '?'] in text so no messages. had food?
#
# Tokens ['ok', 'going', 'to', 'sleep', '.', 'hope', 'i', 'can', 'meet', 'her', '.'] in text ok going to sleep. hope i can meet her.
#
# Tokens ['wat', 'makes', 'some', 'people', 'dearer', 'is', 'not', 'just', 'de', 'happiness', 'dat', 'u', 'feel', 'when', 'u', 'meet', 'them', 'but', 'de', 'pain', 'u', 'feel', 'when', 'u', 'miss', 'dem', '!', '!', '!'] in text wat makes some people dearer is not just de happiness dat u feel when u meet them but de pain u feel when u miss dem!!!
#
# Tokens ['can', 'you', 'let', 'me', 'know', 'details', 'of', 'fri', 'when', 'u', 'find', 'out', 'cos', 'i', "'m", 'not', 'in', 'tom', 'or', 'fri.', 'mentionned', 'chinese', '.', 'thanks'] in text can you let me know details of fri when u find out cos i'm not in tom or fri. mentionned chinese. thanks
#
# Tokens ['you', "'re", 'right', 'i', 'have', 'now', 'that', 'i', 'think', 'about', 'it'] in text you're right i have now that i think about it
#
# Tokens ['wat', 'r', 'u', 'doing', 'now', '?'] in text wat r u doing now?
#
# Tokens ['is', 'ur', 'lecture', 'over', '?'] in text is ur lecture over?
#
# Tokens ['sexy', 'sexy', 'cum', 'and', 'text', 'me', 'im', 'wet', 'and', 'warm', 'and', 'ready', 'for', 'some', 'porn', '!', 'u', 'up', 'for', 'some', 'fun', '?', 'this', 'msg', 'is', 'free', 'recd', 'msgs', '150p', 'inc', 'vat', '2', 'cancel', 'text', 'stop'] in text sexy sexy cum and text me im wet and warm and ready for some porn! u up for some fun? this msg is free recd msgs 150p inc vat 2 cancel text stop
#
# Tokens ['customer', 'place', 'i', 'will', 'call', 'you'] in text customer place i will call you
#
# Tokens ['not', 'planned', 'yet', ':', ')', 'going', 'to', 'join', 'company', 'on', 'jan', '5', 'only.don', 'know', 'what', 'will', 'happen', 'after', 'that', '.'] in text not planned yet :)going to join company on jan 5 only.don know what will happen after that.
#
# Tokens ['boy', ';', 'i', 'love', 'u', 'grl', ':', 'hogolo', 'boy', ':', 'gold', 'chain', 'kodstini', 'grl', ':', 'agalla', 'boy', ':', 'necklace', 'madstini', 'grl', ':', 'agalla', 'boy', ':', 'hogli', '1', 'mutai', 'eerulli', 'kodthini', '!', 'grl', ':', 'i', 'love', 'u', 'kano', ';', '-', ')'] in text boy; i love u grl: hogolo boy: gold chain kodstini grl: agalla boy: necklace madstini grl: agalla boy: hogli 1 mutai eerulli kodthini! grl: i love u kano;-)
#
# Tokens ['haha', 'i', 'heard', 'that', ',', 'text', 'me', 'when', 'you', "'re", 'around'] in text haha i heard that, text me when you're around
#
# Tokens ['i.ll', 'get', 'there', 'tomorrow', 'and', 'send', 'it', 'to', 'you'] in text i.ll get there tomorrow and send it to you
#
# Tokens ['shit', 'babe', '..', 'thasa', 'bit', 'messed', 'up.yeh', ',', 'she', 'shudvetold', 'u.', 'did', 'urgran', 'know', '?', 'neway', ',', 'illspeak', '2', 'u2moro', 'wen', 'im', 'not', 'asleep', '...'] in text shit babe.. thasa bit messed up.yeh, she shudvetold u. did urgran know?neway, illspeak 2 u2moro wen im not asleep...
#
# Tokens ['oh', 'thats', 'late', '!', 'well', 'have', 'a', 'good', 'night', 'and', 'i', 'will', 'give', 'u', 'a', 'call', 'tomorrow', '.', 'iam', 'now', 'going', 'to', 'go', 'to', 'sleep', 'night', 'night'] in text oh thats late! well have a good night and i will give u a call tomorrow. iam now going to go to sleep night night
#
# Tokens ['cheers', 'u', 'tex', 'mecause', 'u', 'werebored', '!', 'yeah', 'okden', 'hunny', 'r', 'uin', 'wk', 'sat', '?', 'sound\x92s', 'likeyour', 'havin', 'gr8fun', 'j', '!', 'keep', 'updat', 'countinlots', 'of', 'loveme', 'xxxxx', '.'] in text cheers u tex mecause u werebored! yeah okden hunny r uin wk sat?sounds likeyour havin gr8fun j! keep updat countinlots of loveme xxxxx.
#
# Tokens ['sorry', ',', 'in', 'meeting', 'i', "'ll", 'call', 'you', 'later'] in text sorry,  in meeting i'll call you later
#
# Tokens ['yo', '!', 'howz', 'u', '?', 'girls', 'never', 'rang', 'after', 'india', '.', 'l'] in text yo! howz u? girls never rang after india. l
#
# Tokens ['yeah', 'but', 'which', 'is', 'worse', 'for', 'i'] in text yeah but which is worse for i
#
# Tokens ['hard', 'live', '121', 'chat', 'just', '60p/min', '.', 'choose', 'your', 'girl', 'and', 'connect', 'live', '.', 'call', '09094646899', 'now', '!', 'cheap', 'chat', 'uk', "'s", 'biggest', 'live', 'service', '.', 'vu', 'bcm1896wc1n3xx'] in text hard live 121 chat just 60p/min. choose your girl and connect live. call 09094646899 now! cheap chat uk's biggest live service. vu bcm1896wc1n3xx
#
# Tokens ['i', 'tagged', 'my', 'friends', 'that', 'you', 'seemed', 'to', 'count', 'as', 'your', 'friends', '.'] in text i tagged my friends that you seemed to count as your friends.
#
# Tokens ['not', 'heard', 'from', 'u4', 'a', 'while', '.', 'call', '4', 'rude', 'chat', 'private', 'line', '01223585334', 'to', 'cum', '.', 'wan', '2c', 'pics', 'of', 'me', 'gettin', 'shagged', 'then', 'text', 'pix', 'to', '8552', '.', '2end', 'send', 'stop', '8552', 'sam', 'xxx'] in text not heard from u4 a while. call 4 rude chat private line 01223585334 to cum. wan 2c pics of me gettin shagged then text pix to 8552. 2end send stop 8552 sam xxx
#
# Tokens ['ok', '...'] in text ok...
#
# Tokens ['long', 'time', '.', 'you', 'remember', 'me', 'today', '.'] in text long time. you remember me today.
#
# Tokens ['havent', 'shopping', 'now', 'lor', 'i', 'juz', 'arrive', 'only'] in text havent shopping now lor i juz arrive only
#
# Tokens ['thank', 'u.', 'it', 'better', 'work', 'out', 'cause', 'i', 'will', 'feel', 'used', 'otherwise'] in text thank u. it better work out cause i will feel used otherwise
#
# Tokens ['are', 'you', 'up', 'for', 'the', 'challenge', '?', 'i', 'know', 'i', 'am', ':', ')'] in text are you up for the challenge? i know i am :)
#
# Tokens ['how', 'much', 'did', 'ur', 'hdd', 'casing', 'cost', '.'] in text how much did ur hdd casing cost.
#
# Tokens ['mystery', 'solved', '!', 'just', 'opened', 'my', 'email', 'and', 'he', "'s", 'sent', 'me', 'another', 'batch', '!', 'is', "n't", 'he', 'a', 'sweetie'] in text mystery solved! just opened my email and he's sent me another batch! isn't he a sweetie
#
# Tokens ['i', 'ca', "n't", 'describe', 'how', 'lucky', 'you', 'are', 'that', 'i', "'m", 'actually', 'awake', 'by', 'noon'] in text i can't describe how lucky you are that i'm actually awake by noon
#
# Tokens ['this', 'is', 'the', '2nd', 'time', 'we', 'have', 'tried', 'to', 'contact', 'u.', 'u', 'have', 'won', 'the', '£1450', 'prize', 'to', 'claim', 'just', 'call', '09053750005', 'b4', '310303.', 't', '&', 'cs/stop', 'sms', '08718725756', '.', '140ppm'] in text this is the 2nd time we have tried to contact u. u have won the £1450 prize to claim just call 09053750005 b4 310303. t&cs/stop sms 08718725756. 140ppm
#
# Tokens ['today', 'is', 'sorry', 'day.', '!', 'if', 'ever', 'i', 'was', 'angry', 'with', 'you', ',', 'if', 'ever', 'i', 'misbehaved', 'or', 'hurt', 'you', '?', 'plz', 'plz', 'just', 'slap', 'urself', 'bcoz', ',', 'its', 'ur', 'fault', ',', 'i', "'m", 'basically', 'good'] in text today is sorry day.! if ever i was angry with you, if ever i misbehaved or hurt you? plz plz just slap urself bcoz, its ur fault, i'm basically good
#
# Tokens ['cheers', 'for', 'the', 'card', '...', 'is', 'it', 'that', 'time', 'of', 'year', 'already', '?'] in text cheers for the card ... is it that time of year already?
#
# Tokens ['hot', 'live', 'fantasies', 'call', 'now', '08707509020', 'just', '20p', 'per', 'min', 'ntt', 'ltd', ',', 'po', 'box', '1327', 'croydon', 'cr9', '5wb', '0870', '..', 'k'] in text hot live fantasies call now 08707509020 just 20p per min ntt ltd, po box 1327 croydon cr9 5wb 0870..k
#
# Tokens ['when', 'people', 'see', 'my', 'msgs', ',', 'they', 'think', 'iam', 'addicted', 'to', 'msging', '...', 'they', 'are', 'wrong', ',', 'bcoz', 'they', "don\\'t", 'know', 'that', 'iam', 'addicted', 'to', 'my', 'sweet', 'friends', '..', '!', '!', 'bslvyl'] in text when people see my msgs, they think iam addicted to msging... they are wrong, bcoz they don\'t know that iam addicted to my sweet friends..!! bslvyl
#
# Tokens ['ugh', 'hopefully', 'the', 'asus', 'ppl', 'dont', 'randomly', 'do', 'a', 'reformat', '.'] in text ugh hopefully the asus ppl dont randomly do a reformat.
#
# Tokens ['have', "n't", 'seen', 'my', 'facebook', ',', 'huh', '?', 'lol', '!'] in text haven't seen my facebook, huh? lol!
#
# Tokens ['mah', 'b', ',', 'i', "'ll", 'pick', 'it', 'up', 'tomorrow'] in text mah b, i'll pick it up tomorrow
#
# Tokens ['still', 'otside', 'le', '..', 'u', 'come', '2morrow', 'maga', '..'] in text still otside le..u come 2morrow maga..
#
# Tokens ['do', 'u', 'still', 'have', 'plumbers', 'tape', 'and', 'a', 'wrench', 'we', 'could', 'borrow', '?'] in text do u still have plumbers tape and a wrench we could borrow?
#
# Tokens ['dear', 'voucher', 'holder', ',', 'to', 'claim', 'this', 'weeks', 'offer', ',', 'at', 'you', 'pc', 'please', 'go', 'to', 'http', ':', '//www.e-tlp.co.uk/reward', '.', 'ts', '&', 'cs', 'apply', '.'] in text dear voucher holder, to claim this weeks offer, at you pc please go to http://www.e-tlp.co.uk/reward. ts&cs apply.
#
# Tokens ['it', 'vl', 'bcum', 'more', 'difficult', '..'] in text it vl bcum more difficult..
#
# Tokens ['ur', 'going', '2', 'bahamas', '!', 'callfreefone', '08081560665', 'and', 'speak', 'to', 'a', 'live', 'operator', 'to', 'claim', 'either', 'bahamas', 'cruise', 'of£2000', 'cash', '18+only', '.', 'to', 'opt', 'out', 'txt', 'x', 'to', '07786200117'] in text ur going 2 bahamas! callfreefone 08081560665 and speak to a live operator to claim either bahamas cruise of£2000 cash 18+only. to opt out txt x to 07786200117
#
# Tokens ['havent', 'still', 'waitin', 'as', 'usual', '...', 'ü', 'come', 'back', 'sch', 'oredi', '?'] in text havent still waitin as usual... ü come back sch oredi?
#
# Tokens ['in', 'meeting', 'da', '.', 'i', 'will', 'call', 'you'] in text in meeting da. i will call you
#
# Tokens ['k', 'k', ':', '-', ')', ':', '-', ')', 'then', 'watch', 'some', 'films', '.'] in text k k :-):-) then watch some films.
#
# Tokens ['does', 'cinema', 'plus', 'drink', 'appeal', 'tomo', '?', '*', 'is', 'a', 'fr', 'thriller', 'by', 'director', 'i', 'like', 'on', 'at', 'mac', 'at', '8.30', '.'] in text does cinema plus drink appeal tomo? * is a fr thriller by director i like on at mac at 8.30.
#
# Tokens ['there', 'the', 'size', 'of', 'elephant', 'tablets', '&', 'u', 'shove', 'um', 'up', 'ur', 'ass', '!', '!'] in text there the size of elephant tablets & u shove um up ur ass!!
#
# Tokens ['so', 'many', 'people', 'seems', 'to', 'be', 'special', 'at', 'first', 'sight', ',', 'but', 'only', 'very', 'few', 'will', 'remain', 'special', 'to', 'you', 'till', 'your', 'last', 'sight', '..', 'maintain', 'them', 'till', 'life', 'ends', '..', 'take', 'cr', 'da'] in text so many people seems to be special at first sight, but only very few will remain special to you till your last sight.. maintain them till life ends.. take cr da
#
# Tokens ['my', 'parents', ',', 'my', 'kidz', ',', 'my', 'friends', 'n', 'my', 'colleagues', '.', 'all', 'screaming', '..', 'surprise', '!', '!', 'and', 'i', 'was', 'waiting', 'on', 'the', 'sofa', '..', '...', '.....', "'", 'naked', '...', '!'] in text my parents, my kidz, my friends n my colleagues. all screaming.. surprise !! and i was waiting on the sofa.. ... ..... ' naked...!
#
# Tokens ['dunno', 'i', 'juz', 'askin', 'cos', 'i', 'got', 'a', 'card', 'got', '20', '%', 'off', '4', 'a', 'salon', 'called', 'hair', 'sense', 'so', 'i', 'tot', 'it', "'s", 'da', 'one', 'ü', 'cut', 'ur', 'hair', '.'] in text dunno i juz askin cos i got a card got 20% off 4 a salon called hair sense so i tot it's da one ü cut ur hair.
#
# Tokens ['good', 'morning', 'pookie', 'pie', '!', 'lol', 'hope', 'i', 'did', "n't", 'wake', 'u', 'up'] in text good morning pookie pie! lol hope i didn't wake u up
#
# Tokens ['maybe', 'if', 'you', 'woke', 'up', 'before', 'fucking', '3', 'this', 'would', "n't", 'be', 'a', 'problem', '.'] in text maybe if you woke up before fucking 3 this wouldn't be a problem.
#
# Tokens ['happy', 'birthday', 'to', 'you', '....', 'dear.with', 'lots', 'of', 'love.rakhesh', 'nri'] in text happy birthday to you....dear.with lots of love.rakhesh nri
#
# Tokens ['howz', 'that', 'persons', 'story'] in text howz that persons story
#
# Tokens ['this', 'is', 'the', '2nd', 'time', 'we', 'have', 'tried', '2', 'contact', 'u.', 'u', 'have', 'won', 'the', '750', 'pound', 'prize', '.', '2', 'claim', 'is', 'easy', ',', 'call', '08712101358', 'now', '!', 'only', '10p', 'per', 'min', '.', 'bt-national-rate'] in text this is the 2nd time we have tried 2 contact u. u have won the 750 pound prize. 2 claim is easy, call 08712101358 now! only 10p per min. bt-national-rate
#
# Tokens ['x2', '&', 'lt', ';', '#', '&', 'gt', ';', '.', 'are', 'you', 'going', 'to', 'get', 'that'] in text x2  &lt;#&gt; . are you going to get that
#
# Tokens ['hi', 'neva', 'worry', 'bout', 'da', 'truth', 'coz', 'the', 'truth', 'will', 'lead', 'me', '2', 'ur', 'heart', '.', 'it\x92s', 'the', 'least', 'a', 'unique', 'person', 'like', 'u', 'deserve', '.', 'sleep', 'tight', 'or', 'morning'] in text hi neva worry bout da truth coz the truth will lead me 2 ur heart. its the least a unique person like u deserve. sleep tight or morning
#
# Tokens ['ur', 'awarded', 'a', 'city', 'break', 'and', 'could', 'win', 'a', '£200', 'summer', 'shopping', 'spree', 'every', 'wk', '.', 'txt', 'store', 'to', '88039.skilgme.tscs087147403231winawk', '!', 'age16+£1.50perwksub'] in text ur awarded a city break and could win a £200 summer shopping spree every wk. txt store to 88039.skilgme.tscs087147403231winawk!age16+£1.50perwksub
#
# Tokens ['is', 'ur', 'paper', 'today', 'in', 'e', 'morn', 'or', 'aft', '?'] in text is ur paper today in e morn or aft?
#
# Tokens ['i', 'will', 'lick', 'up', 'every', 'drop', ':', ')', 'are', 'you', 'ready', 'to', 'use', 'your', 'mouth', 'as', 'well', '?'] in text i will lick up every drop :) are you ready to use your mouth as well?
#
# Tokens ['and', 'you', '!', 'will', 'expect', 'you', 'whenever', 'you', 'text', '!', 'hope', 'all', 'goes', 'well', 'tomo'] in text and you! will expect you whenever you text! hope all goes well tomo
#
# Tokens ['great', '.', 'p', 'diddy', 'is', 'my', 'neighbor', 'and', 'comes', 'for', 'toothpaste', 'every', 'morning'] in text great. p diddy is my neighbor and comes for toothpaste every morning
#
# Tokens ['i', 'av', 'a', 'new', 'number', ',', '.', 'wil', 'u', 'only', 'use', 'this', 'one', ',', 'ta', '.'] in text i av a new number,  . wil u only use this one,ta.
#
# Tokens ['so', 'its', 'to', 'be', 'poking', 'man', 'everyday', 'that', 'they', 'teach', 'you', 'in', 'canada', 'abi', '!', 'how', 'are', 'you', '.', 'just', 'saying', 'hi', '.'] in text so its to be poking man everyday that they teach you in canada abi! how are you. just saying hi.
#
# Tokens ['7', 'lor', '...', 'change', '2', 'suntec', '...', 'wat', 'time', 'u', 'coming', '?'] in text 7 lor... change 2 suntec... wat time u coming?
#
# Tokens ['no', 'de.am', 'seeing', 'in', 'online', 'shop', 'so', 'that', 'i', 'asked', '.'] in text no de.am seeing in online shop so that i asked.
#
# Tokens ['just', 'curious', 'because', 'my', 'cuz', 'asked', 'what', 'i', 'was', 'up', 'to'] in text just curious because my cuz asked what i was up to
#
# Tokens ['nice.nice.how', 'is', 'it', 'working', '?'] in text nice.nice.how is it working?
#
# Tokens ['okay', 'lor', '...', 'wah', '...', 'like', 'that', 'def', 'they', 'wont', 'let', 'us', 'go', '...', 'haha', '...', 'what', 'did', 'they', 'say', 'in', 'the', 'terms', 'and', 'conditions', '?'] in text okay lor... wah... like that def they wont let us go... haha... what did they say in the terms and conditions?
#
# Tokens ['haha', '...', 'yup', 'hopefully', 'we', 'will', 'lose', 'a', 'few', 'kg', 'by', 'mon', '.', 'after', 'hip', 'hop', 'can', 'go', 'orchard', 'and', 'weigh', 'again'] in text haha... yup hopefully  we will lose a few kg by mon. after hip hop can go orchard and weigh again
#
# Tokens ['she', "'s", 'good', '.', 'how', 'are', 'you', '.', 'where', 'r', 'u', 'working', 'now'] in text she's good. how are you. where r u working now
#
# Tokens ['oh', ',', 'yes', ',', 'i', "'ve", 'just', 'been', 'a', 'little', 'under', 'the', 'weather', 'so', 'i', "'ve", 'kind', 'of', 'been', 'coccooning', 'at', 'home'] in text oh, yes, i've just been a little under the weather so i've kind of been coccooning at home
#
# Tokens ['at', 'home', 'also', '.'] in text at home also.
#
# Tokens ['this', 'phone', 'has', 'the', 'weirdest', 'auto', 'correct', '.'] in text this phone has the weirdest auto correct.
#
# Tokens ['oops', 'my', 'phone', 'died', 'and', 'i', 'did', "n't", 'even', 'know', '.', 'yeah', 'i', 'like', 'it', 'better', '.'] in text oops my phone died and i didn't even know. yeah i like it better.
#
# Tokens ['havent', 'mus', 'ask', 'if', 'u', 'can', '1st', 'wat', '.', 'of', 'meet', '4', 'lunch', 'den', 'u', 'n', 'him', 'meet', 'can', 'already', 'lor', '.', 'or', 'u', 'wan', '2', 'go', 'ask', 'da', 'ge', '1st', 'then', 'confirm', 'w', 'me', 'asap', '?'] in text havent mus ask if u can 1st wat. of meet 4 lunch den u n him meet can already lor. or u wan 2 go ask da ge 1st then confirm w me asap?
#
# Tokens ['she', 'said', ',', "''", 'do', 'u', 'mind', 'if', 'i', 'go', 'into', 'the', 'bedroom', 'for', 'a', 'minute', '?', '``', "''", 'ok', "''", ',', 'i', 'sed', 'in', 'a', 'sexy', 'mood', '.', 'she', 'came', 'out', '5', 'minuts', 'latr', 'wid', 'a', 'cake', '...', 'n', 'my', 'wife', ','] in text she said,'' do u mind if i go into the bedroom for a minute ? '' ''ok'', i sed in a sexy mood. she came out 5 minuts latr wid a cake...n my wife,
#
# Tokens ['oh', 'yeah', ',', 'and', 'hav', 'a', 'great', 'time', 'in', 'newquay-send', 'me', 'a', 'postcard', '!', '1', 'look', 'after', 'all', 'the', 'girls', 'while', 'im', 'gone', '(', 'u', 'know', 'the', '1im', 'talkin', 'bout', '!', ')', 'xx'] in text oh yeah,and hav a great time in newquay-send me a postcard !1 look after all the girls while im gone(u know the 1im talkin bout!)xx
#
# Tokens ['we', 'got', 'a', 'divorce', '.', 'lol', '.', 'she.s', 'here'] in text we got a divorce. lol. she.s here
#
# Tokens ['what', "'s", 'ur', 'pin', '?'] in text what's ur pin?
#
# Tokens ['babe', ',', 'have', 'you', 'got', 'enough', 'money', 'to', 'pick', 'up', 'bread', 'and', 'milk', '?', 'and', 'i', "'ll", 'give', 'you', 'it', 'back', 'when', 'you', 'get', 'home', '?'] in text babe, have you got enough money to pick up bread and milk ? and i'll give you it back when you get home ?
#
# Tokens ['i', 'want', 'snow', '.', 'it', "'s", 'just', 'freezing', 'and', 'windy', '.'] in text i want snow. it's just freezing and windy.
#
# Tokens ['urgent', '!', 'we', 'are', 'trying', 'to', 'contact', 'u.', 'todays', 'draw', 'shows', 'that', 'you', 'have', 'won', 'a', '£2000', 'prize', 'guaranteed', '.', 'call', '09066358361', 'from', 'land', 'line', '.', 'claim', 'y87', '.', 'valid', '12hrs', 'only'] in text urgent! we are trying to contact u. todays draw shows that you have won a £2000 prize guaranteed. call 09066358361 from land line. claim y87. valid 12hrs only
#
# Tokens ['come', 'to', 'mahal', 'bus', 'stop', '..', '&', 'lt', ';', 'decimal', '&', 'gt', ';'] in text come to mahal bus stop.. &lt;decimal&gt;
#
# Tokens ['don', 'know', ':', ')', 'this', 'week', 'i', "'m", 'going', 'to', 'tirunelvai', 'da', '.'] in text don know:)this week i'm going to tirunelvai da.
#
# Tokens ['me', 'too', 'baby', '!', 'i', 'promise', 'to', 'treat', 'you', 'well', '!', 'i', 'bet', 'you', 'will', 'take', 'good', 'care', 'of', 'me', '...'] in text me too baby! i promise to treat you well! i bet you will take good care of me...
#
# Tokens ['its', 'like', 'that', 'hotel', 'dusk', 'game', 'i', 'think', '.', 'you', 'solve', 'puzzles', 'in', 'a', 'area', 'thing'] in text its like that hotel dusk game i think. you solve puzzles in a area thing
#
# Tokens ['thanks', 'for', 'your', 'ringtone', 'order', ',', 'reference', 'number', 'x29', '.', 'your', 'mobile', 'will', 'be', 'charged', '4.50.', 'should', 'your', 'tone', 'not', 'arrive', 'please', 'call', 'customer', 'services', '09065989180'] in text thanks for your ringtone order, reference number x29. your mobile will be charged 4.50. should your tone not arrive please call customer services 09065989180
#
# Tokens ['hi', ',', 'my', 'love', '!', 'how', 'goes', 'that', 'day', '?', 'fuck', ',', 'this', 'morning', 'i', 'woke', 'and', 'dropped', 'my', 'cell', 'on', 'the', 'way', 'down', 'the', 'stairs', 'but', 'it', 'seems', 'alright', '...', '*', 'phews', '*', 'i', 'miss', 'you', '!'] in text hi, my love! how goes that day? fuck, this morning i woke and dropped my cell on the way down the stairs but it seems alright ... *phews* i miss you !
#
# Tokens ['well', 'that', 'must', 'be', 'a', 'pain', 'to', 'catch'] in text well that must be a pain to catch
#
# Tokens ['sorry', 'da', 'thangam.it', "'s", 'my', 'mistake', '.'] in text sorry da thangam.it's my mistake.
#
# Tokens ['i', 'need', '...', 'coz', 'i', 'never', 'go', 'before'] in text i need... coz i never go before
#
# Tokens ['rose', 'for', 'red', ',', 'red', 'for', 'blood', ',', 'blood', 'for', 'heart', ',', 'heart', 'for', 'u.', 'but', 'u', 'for', 'me', '....', 'send', 'tis', 'to', 'all', 'ur', 'friends', '..', 'including', 'me', '..', 'if', 'u', 'like', 'me', '..', 'if', 'u', 'get', 'back', ',', '1-u', 'r', 'poor', 'in', 'relation', '!', '2-u', 'need', 'some', '1', 'to', 'support', '3-u', 'r', 'frnd', '2', 'many', '4-some1', 'luvs', 'u', '5+-', 'some1', 'is', 'praying', 'god', 'to', 'marry', 'u.', ':', '-', ')', 'try', 'it', '....'] in text rose for red,red for blood,blood for heart,heart for u. but u for me.... send tis to all ur friends.. including me.. if u like me.. if u get back, 1-u r poor in relation! 2-u need some 1 to support 3-u r frnd 2 many 4-some1 luvs u 5+- some1 is praying god to marry u.:-) try it....
#
# Tokens ['wife.how', 'she', 'knew', 'the', 'time', 'of', 'murder', 'exactly'] in text wife.how she knew the time of murder exactly
#
# Tokens ['six', 'chances', 'to', 'win', 'cash', '!', 'from', '100', 'to', '20,000', 'pounds', 'txt', '>', 'csh11', 'and', 'send', 'to', '87575.', 'cost', '150p/day', ',', '6days', ',', '16+', 'tsandcs', 'apply', 'reply', 'hl', '4', 'info'] in text six chances to win cash! from 100 to 20,000 pounds txt> csh11 and send to 87575. cost 150p/day, 6days, 16+ tsandcs apply reply hl 4 info
#
# Tokens ['ur', 'cash-balance', 'is', 'currently', '500', 'pounds', '-', 'to', 'maximize', 'ur', 'cash-in', 'now', 'send', 'collect', 'to', '83600', 'only', '150p/msg', '.', 'cc', ':', '08718720201', 'po', 'box', '114/14', 'tcr/w1'] in text ur cash-balance is currently 500 pounds - to maximize ur cash-in now send collect to 83600 only 150p/msg. cc: 08718720201 po box 114/14 tcr/w1
#
# Tokens ['i', 'feel', 'like', 'a', 'dick', 'because', 'i', 'keep', 'sleeping', 'through', 'your', 'texts', 'and', 'facebook', 'messages', '.', 'sup', ',', 'you', 'in', 'town', '?'] in text i feel like a dick because i keep sleeping through your texts and facebook messages. sup, you in town?
#
# Tokens ['no', 'plm', 'i', 'will', 'come', 'da', '.', 'on', 'the', 'way', '.'] in text no plm i will come da. on the way.
#
# Tokens ['guess', 'he', 'wants', 'alone', 'time', '.', 'we', 'could', 'just', 'show', 'up', 'and', 'watch', 'when', 'they', 'do', '..'] in text guess he wants alone time. we could just show up and watch when they do..
#
# Tokens ['height', 'of', 'recycling', ':', 'read', 'twice-', 'people', 'spend', 'time', 'for', 'earning', 'money', 'and', 'the', 'same', 'money', 'is', 'spent', 'for', 'spending', 'time', '!', ';', '-', ')', 'good', 'morning', '..', 'keep', 'smiling', ':', '-', ')'] in text height of recycling: read twice- people spend time for earning money and the same money is spent for spending time!;-) good morning.. keep smiling:-)
#
# Tokens ['yup', 'ü', 'not', 'comin', ':', '-', '('] in text yup ü not comin :-(
#
# Tokens ['yes', ',', 'princess', '.', 'toledo', '.'] in text yes, princess. toledo.
#
# Tokens ['aight', 'text', 'me', 'when', 'you', "'re", 'back', 'at', 'mu', 'and', 'i', "'ll", 'swing', 'by', ',', 'need', 'somebody', 'to', 'get', 'the', 'door', 'for', 'me'] in text aight text me when you're back at mu and i'll swing by, need somebody to get the door for me
#
# Tokens ['ron', 'say', 'fri', 'leh', '.', 'n', 'he', 'said', 'ding', 'tai', 'feng', 'cant', 'make', 'reservations', '.', 'but', 'he', 'said', 'wait', 'lor', '.'] in text ron say fri leh. n he said ding tai feng cant make reservations. but he said wait lor.
#
# Tokens ['good', '.', 'no', 'swimsuit', 'allowed', ':', ')'] in text good. no swimsuit allowed :)
#
# Tokens ['am', 'okay', '.', 'will', 'soon', 'be', 'over', '.', 'all', 'the', 'best'] in text am okay. will soon be over. all the best
#
# Tokens ['a', 'cute', 'thought', 'for', 'friendship', ':', '``', 'its', 'not', 'necessary', 'to', 'share', 'every', 'secret', 'with', 'ur', 'close', 'frnd', ',', 'but', 'watever', 'u', 'shared', 'should', 'be', 'true', "''", '....'] in text a cute thought for friendship: "its not necessary to share every secret with ur close frnd, but watever u shared should be true"....
#
# Tokens ['ok', 'i', "'ve", 'sent', 'u', 'da', 'latest', 'version', 'of', 'da', 'project', '.'] in text ok i've sent u da latest version of da project.
#
# Tokens ['good', 'morning', 'my', 'dear', '...........', 'have', 'a', 'great', '&', 'amp', ';', 'successful', 'day', '.'] in text good morning my dear........... have a great &amp; successful day.
#
# Tokens ['pls', 'accept', 'me', 'for', 'one', 'day', '.', 'or', 'am', 'begging', 'you', 'change', 'the', 'number', '.'] in text pls accept me for one day. or am begging you change the number.
#
# Tokens ['squeeeeeze', '!', '!', 'this', 'is', 'christmas', 'hug', '..', 'if', 'u', 'lik', 'my', 'frndshp', 'den', 'hug', 'me', 'back', '..', 'if', 'u', 'get', '3', 'u', 'r', 'cute', ':', ')', '6', 'u', 'r', 'luvd', ':', '*', '9', 'u', 'r', 'so', 'lucky', ';', ')', 'none', '?', 'people', 'hate', 'u', ':'] in text squeeeeeze!! this is christmas hug.. if u lik my frndshp den hug me back.. if u get 3 u r cute:) 6 u r luvd:* 9 u r so lucky;) none? people hate u:
#
# Tokens ['its', 'ok', ',', 'if', 'anybody', 'asks', 'abt', 'me', ',', 'u', 'tel', 'them', '..', ':', '-p'] in text its ok, if anybody asks abt me, u tel them..:-p
#
# Tokens ['funny', 'fact', 'nobody', 'teaches', 'volcanoes', '2', 'erupt', ',', 'tsunamis', '2', 'arise', ',', 'hurricanes', '2', 'sway', 'aroundn', 'no', '1', 'teaches', 'hw', '2', 'choose', 'a', 'wife', 'natural', 'disasters', 'just', 'happens'] in text funny fact nobody teaches volcanoes 2 erupt, tsunamis 2 arise, hurricanes 2 sway aroundn no 1 teaches hw 2 choose a wife natural disasters just happens
#
# Tokens ['*', 'you', 'gon', 'na', 'ring', 'this', 'weekend', 'or', 'wot', '?'] in text * you gonna ring this weekend or wot?
#
# Tokens ['also', 'track', 'down', 'any', 'lighters', 'you', 'can', 'find'] in text also track down any lighters you can find
#
# Tokens ['sorry', ',', 'i', 'ca', "n't", 'help', 'you', 'on', 'this', '.'] in text sorry, i can't help you on this.
#
# Tokens ['babe', ',', 'i', 'need', 'your', 'advice'] in text babe, i need your advice
#
# Tokens ['i', '‘', 'll', 'leave', 'around', 'four', ',', 'ok', '?'] in text i‘ll leave around four, ok?
#
# Tokens ['come', 'to', 'medical', 'college', 'at', '7pm', '......', 'forward', 'it', 'da'] in text come to medical college at 7pm ......forward it da
#
# Tokens ['k', ':', ')', 'k', '..', 'its', 'good', ':', ')', 'when', 'are', 'you', 'going', '?'] in text k:)k..its good:)when are you going?
#
# Tokens ['i', 'can', 'make', 'lasagna', 'for', 'you', '...', 'vodka', '...'] in text i can make lasagna for you... vodka...
#
# Tokens ['hi', 'its', 'kate', 'can', 'u', 'give', 'me', 'a', 'ring', 'asap', 'xxx'] in text hi its kate can u give me a ring asap xxx
#
# Tokens ['who', 'were', 'those', 'people', '?', 'were', 'you', 'in', 'a', 'tour', '?', 'i', 'thought', 'you', 'were', 'doing', 'that', 'sofa', 'thing', 'you', 'sent', 'me', '?', 'your', 'curious', 'sugar'] in text who were those people ? were you in a tour ? i thought you were doing that sofa thing you sent me ? your curious sugar
#
# Tokens ['no', ',', 'but', 'you', 'told', 'me', 'you', 'were', 'going', ',', 'before', 'you', 'got', 'drunk', '!'] in text no, but you told me you were going, before you got drunk!
#
# Tokens ['he', 'fucking', 'chickened', 'out', '.', 'he', 'messaged', 'me', 'he', 'would', 'be', 'late', 'and', 'woould', 'buzz', 'me', 'and', 'then', 'i', 'did', "n't", 'hear', 'a', 'word', 'from', 'him'] in text he fucking chickened out. he messaged me he would be late and woould buzz me and then i didn't hear a word from him
#
# Tokens ['congratulations', '!', 'thanks', 'to', 'a', 'good', 'friend', 'u', 'have', 'won', 'the', '£2,000', 'xmas', 'prize', '.', '2', 'claim', 'is', 'easy', ',', 'just', 'call', '08718726978', 'now', '!', 'only', '10p', 'per', 'minute', '.', 'bt-national-rate'] in text congratulations! thanks to a good friend u have won the £2,000 xmas prize. 2 claim is easy, just call 08718726978 now! only 10p per minute. bt-national-rate
#
# Tokens ['i', "'m", 'always', 'looking', 'for', 'an', 'excuse', 'to', 'be', 'in', 'the', 'city', '.'] in text i'm always looking for an excuse to be in the city.
#
# Tokens ['yup', 'i', "'m", 'still', 'having', 'coffee', 'wif', 'my', 'frens', '...', 'my', 'fren', 'drove', 'she', "'ll", 'give', 'me', 'a', 'lift', '...'] in text yup i'm still having coffee wif my frens... my fren drove she'll give me a lift...
#
# Tokens ['o', 'shore', 'are', 'you', 'takin', 'the', 'bus'] in text o shore are you takin the bus
#
# Tokens ['so', 'u', 'gon', 'na', 'get', 'deus', 'ex', '?'] in text so u gonna get deus ex?
#
# Tokens ['i', 'will', 'send', 'them', 'to', 'your', 'email', '.', 'do', 'you', 'mind', '&', 'lt', ';', '#', '&', 'gt', ';', 'times', 'per', 'night', '?'] in text i will send them to your email. do you mind  &lt;#&gt;  times per night?
#
# Tokens ['44', '7732584351', ',', 'do', 'you', 'want', 'a', 'new', 'nokia', '3510i', 'colour', 'phone', 'deliveredtomorrow', '?', 'with', '300', 'free', 'minutes', 'to', 'any', 'mobile', '+', '100', 'free', 'texts', '+', 'free', 'camcorder', 'reply', 'or', 'call', '08000930705', '.'] in text 44 7732584351, do you want a new nokia 3510i colour phone deliveredtomorrow? with 300 free minutes to any mobile + 100 free texts + free camcorder reply or call 08000930705.
#
# Tokens ['tap', '&', 'spile', 'at', 'seven', '.', '*', 'is', 'that', 'pub', 'on', 'gas', 'st', 'off', 'broad', 'st', 'by', 'canal', '.', 'ok', '?'] in text tap & spile at seven. * is that pub on gas st off broad st by canal. ok?
#
# Tokens ['ok', 'then', 'i', 'come', 'n', 'pick', 'u', 'at', 'engin', '?'] in text ok then i come n pick u at engin?
#
# Tokens ['which', 'is', 'why', 'i', 'never', 'wanted', 'to', 'tell', 'you', 'any', 'of', 'this', '.', 'which', 'is', 'why', 'i', "'m", 'so', 'short', 'with', 'you', 'and', 'on-edge', 'as', 'of', 'late', '.'] in text which is why i never wanted to tell you any of this. which is why i'm so short with you and on-edge as of late.
#
# Tokens ['raviyog', 'peripherals', 'bhayandar', 'east'] in text raviyog peripherals bhayandar east
#
# Tokens ['k', 'actually', 'can', 'you', 'guys', 'meet', 'me', 'at', 'the', 'sunoco', 'on', 'howard', '?', 'it', 'should', 'be', 'right', 'on', 'the', 'way'] in text k actually can you guys meet me at the sunoco on howard? it should be right on the way
#
# Tokens ['you', 'have', '1', 'new', 'voicemail', '.', 'please', 'call', '08719181513', '.'] in text you have 1 new voicemail. please call 08719181513.
#
# Tokens ['moon', 'has', 'come', 'to', 'color', 'your', 'dreams', ',', 'stars', 'to', 'make', 'them', 'musical', 'and', 'my', 'sms', 'to', 'give', 'you', 'warm', 'and', 'peaceful', 'sleep', '.', 'good', 'night'] in text moon has come to color your dreams, stars to make them musical and my sms to give you warm and peaceful sleep. good night
#
# Tokens ['just', 'finished', 'eating', '.', 'got', 'u', 'a', 'plate', '.', 'not', 'leftovers', 'this', 'time', '.'] in text just finished eating. got u a plate. not leftovers this time.
#
# Tokens ['thanx', 'a', 'lot', '...'] in text thanx a lot...
#
# Tokens ['hurry', 'home', 'u', 'big', 'butt', '.', 'hang', 'up', 'on', 'your', 'last', 'caller', 'if', 'u', 'have', 'to', '.', 'food', 'is', 'done', 'and', 'i', "'m", 'starving', '.', 'do', "n't", 'ask', 'what', 'i', 'cooked', '.'] in text hurry home u big butt. hang up on your last caller if u have to. food is done and i'm starving. don't ask what i cooked.
#
# Tokens ['lol', 'your', 'right', '.', 'what', 'diet', '?', 'everyday', 'i', 'cheat', 'anyway', '.', 'i', "'m", 'meant', 'to', 'be', 'a', 'fatty', ':', '('] in text lol your right. what diet? everyday i cheat anyway. i'm meant to be a fatty :(
#
# Tokens ['its', 'a', 'great', 'day', '.', 'do', 'have', 'yourself', 'a', 'beautiful', 'one', '.'] in text its a great day. do have yourself a beautiful one.
#
# Tokens ['what', 'happened', 'in', 'interview', '?'] in text what happened in interview?
#
# ...
#
# Tokens ['god', "'s", 'love', 'has', 'no', 'limit', '.', 'god', "'s", 'grace', 'has', 'no', 'measure', '.', 'god', "'s", 'power', 'has', 'no', 'boundaries', '.', 'may', 'u', 'have', 'god', "'s", 'endless', 'blessings', 'always', 'in', 'ur', 'life', '...', '!', '!', 'gud', 'ni8'] in text god's love has no limit. god's grace has no measure. god's power has no boundaries. may u have god's endless blessings always in ur life...!! gud ni8
#
# Tokens ['i', 'want', 'to', 'be', 'inside', 'you', 'every', 'night', '...'] in text i want to be inside you every night...
#
# Tokens ['machan', 'you', 'go', 'to', 'gym', 'tomorrow', ',', 'i', 'wil', 'come', 'late', 'goodnight', '.'] in text machan you go to gym tomorrow,  i wil come late goodnight.
#
# Tokens ['lol', 'they', 'were', 'mad', 'at', 'first', 'but', 'then', 'they', 'woke', 'up', 'and', 'gave', 'in', '.'] in text lol they were mad at first but then they woke up and gave in.
#
# Tokens ['i', 'went', 'to', 'project', 'centre'] in text i went to project centre
#
# Tokens ['it', '‘', 's', 'reassuring', ',', 'in', 'this', 'crazy', 'world', '.'] in text it‘s reassuring, in this crazy world.
#
# Tokens ['just', 'making', 'dinner', ',', 'you', '?'] in text just making dinner, you ?
#
# Tokens ['yes', '.', 'please', 'leave', 'at', '&', 'lt', ';', '#', '&', 'gt', ';', '.', 'so', 'that', 'at', '&', 'lt', ';', '#', '&', 'gt', ';', 'we', 'can', 'leave'] in text yes. please leave at  &lt;#&gt; . so that at  &lt;#&gt;  we can leave
#
# Tokens ['oh', '...', 'okie', 'lor', '...', 'we', 'go', 'on', 'sat', '...'] in text oh... okie lor...we go on sat...
#
# Tokens ['you', 'are', 'a', 'great', 'role', 'model', '.', 'you', 'are', 'giving', 'so', 'much', 'and', 'i', 'really', 'wish', 'each', 'day', 'for', 'a', 'miracle', 'but', 'god', 'as', 'a', 'reason', 'for', 'everything', 'and', 'i', 'must', 'say', 'i', 'wish', 'i', 'knew', 'why', 'but', 'i', 'dont', '.', 'i', "'ve", 'looked', 'up', 'to', 'you', 'since', 'i', 'was', 'young', 'and', 'i', 'still', 'do', '.', 'have', 'a', 'great', 'day', '.'] in text you are a great role model. you are giving so much and i really wish each day for a miracle but god as a reason for everything and i must say i wish i knew why but i dont. i've looked up to you since i was young and i still do. have a great day.
#
# Tokens ['ya', ',', 'i', "'m", 'referin', 'to', 'mei', "'s", 'ex', 'wat', '...', 'no', 'ah', ',', 'waitin', '4', 'u', 'to', 'treat', ',', 'somebody', 'shld', 'b', 'rich', 'liao', '...', 'so', 'gd', ',', 'den', 'u', 'dun', 'have', 'to', 'work', 'frm', 'tmr', 'onwards', '...'] in text ya, i'm referin to mei's ex wat... no ah, waitin 4 u to treat, somebody shld b rich liao...so gd, den u dun have to work frm tmr onwards...
#
# Tokens ['miles', 'and', 'smiles', 'r', 'made', 'frm', 'same', 'letters', 'but', 'do', 'u', 'know', 'd', 'difference', '..', '?', 'smile', 'on', 'ur', 'face', 'keeps', 'me', 'happy', 'even', 'though', 'i', 'am', 'miles', 'away', 'from', 'u', '..', ':', '-', ')', 'keep', 'smiling', '..', 'good', 'nyt'] in text miles and smiles r made frm same letters but do u know d difference..? smile on ur face keeps me happy even though i am miles away from u.. :-)keep smiling.. good nyt
#
# Tokens ['by', 'the', 'way', ',', 'i', "'ve", 'put', 'a', 'skip', 'right', 'outside', 'the', 'front', 'of', 'the', 'house', 'so', 'you', 'can', 'see', 'which', 'house', 'it', 'is', '.', 'just', 'pull', 'up', 'before', 'it', '.'] in text by the way, i've put a skip right outside the front of the house so you can see which house it is. just pull up before it.
#
# Tokens ['can', 'you', 'pls', 'send', 'me', 'that', 'company', 'name', '.', 'in', 'saibaba', 'colany'] in text can you pls send me that company name. in saibaba colany
#
# Tokens ['no', '.', 'i', 'dont', 'want', 'to', 'hear', 'anything'] in text no. i dont want to hear anything
#
# Tokens ['you', 'are', 'a', 'big', 'chic', '.', 'common', '.', 'declare'] in text you are a big chic. common. declare
#
# Tokens ['thats', 'cool', '.', 'i', 'want', 'to', 'please', 'you', '...'] in text thats cool. i want to please you...
#
# Tokens ['going', 'to', 'join', 'tomorrow', '.'] in text going to join tomorrow.
#
# Tokens ['you', 'are', 'awarded', 'a', 'sipix', 'digital', 'camera', '!', 'call', '09061221061', 'from', 'landline', '.', 'delivery', 'within', '28days', '.', 't', 'cs', 'box177', '.', 'm221bp', '.', '2yr', 'warranty', '.', '150ppm', '.', '16', '.', 'p', 'p£3.99'] in text you are awarded a sipix digital camera! call 09061221061 from landline. delivery within 28days. t cs box177. m221bp. 2yr warranty. 150ppm. 16 . p p£3.99
#
# Tokens ['i', 'want', 'to', 'tell', 'you', 'how', 'bad', 'i', 'feel', 'that', 'basically', 'the', 'only', 'times', 'i', 'text', 'you', 'lately', 'are', 'when', 'i', 'need', 'drugs'] in text i want to tell you how bad i feel that basically the only times i text you lately are when i need drugs
#
# Tokens ['private', '!', 'your', '2003', 'account', 'statement', 'for', 'shows', '800', 'un-redeemed', 's.i.m', '.', 'points', '.', 'call', '08718738001', 'identifier', 'code', ':', '49557', 'expires', '26/11/04'] in text private! your 2003 account statement for shows 800 un-redeemed s.i.m. points. call 08718738001 identifier code: 49557 expires 26/11/04
#
# Tokens ['total', 'disappointment', ',', 'when', 'i', 'texted', 'you', 'was', 'the', 'craziest', 'shit', 'got', ':', '('] in text total disappointment, when i texted you was the craziest shit got :(
#
# Tokens ['its', 'just', 'the', 'effect', 'of', 'irritation', '.', 'just', 'ignore', 'it'] in text its just the effect of irritation. just ignore it
#
# Tokens ['what', 'about', 'this', 'one', 'then', '.'] in text what about this one then.
#
# Tokens ['i', 'think', 'that', 'tantrum', "'s", 'finished', 'so', 'yeah', 'i', "'ll", 'be', 'by', 'at', 'some', 'point'] in text i think that tantrum's finished so yeah i'll be by at some point
#
# Tokens ['compliments', 'to', 'you', '.', 'was', 'away', 'from', 'the', 'system', '.', 'how', 'your', 'side', '.'] in text compliments to you. was away from the system. how your side.
#
# Tokens ['happened', 'here', 'while', 'you', 'were', 'adventuring'] in text happened here while you were adventuring
#
# Tokens ['hey', 'chief', ',', 'can', 'you', 'give', 'me', 'a', 'bell', 'when', 'you', 'get', 'this', '.', 'need', 'to', 'talk', 'to', 'you', 'about', 'this', 'royal', 'visit', 'on', 'the', '1st', 'june', '.'] in text hey chief, can you give me a bell when you get this. need to talk to you about this royal visit on the 1st june.
#
# Tokens ['ok', 'which', 'your', 'another', 'number'] in text ok which your another number
#
# Tokens ['i', 'know', 'you', 'are', 'thinkin', 'malaria', '.', 'but', 'relax', ',', 'children', 'cant', 'handle', 'malaria', '.', 'she', 'would', 'have', 'been', 'worse', 'and', 'its', 'gastroenteritis', '.', 'if', 'she', 'takes', 'enough', 'to', 'replace', 'her', 'loss', 'her', 'temp', 'will', 'reduce', '.', 'and', 'if', 'you', 'give', 'her', 'malaria', 'meds', 'now', 'she', 'will', 'just', 'vomit', '.', 'its', 'a', 'self', 'limiting', 'illness', 'she', 'has', 'which', 'means', 'in', 'a', 'few', 'days', 'it', 'will', 'completely', 'stop'] in text i know you are thinkin malaria. but relax, children cant handle malaria. she would have been worse and its gastroenteritis. if she takes enough to replace her loss her temp will reduce. and if you give her malaria meds now she will just vomit. its a self limiting illness she has which means in a few days it will completely stop
#
# Tokens ['aiyah', 'ok', 'wat', 'as', 'long', 'as', 'got', 'improve', 'can', 'already', 'wat', '...'] in text aiyah ok wat as long as got improve can already wat...
#
# Tokens ['want', 'explicit', 'sex', 'in', '30', 'secs', '?', 'ring', '02073162414', 'now', '!', 'costs', '20p/min', 'gsex', 'pobox', '2667', 'wc1n', '3xx'] in text want explicit sex in 30 secs? ring 02073162414 now! costs 20p/min gsex pobox 2667 wc1n 3xx
#
# Tokens ['i', 'ca', "n't", 'believe', 'how', 'attached', 'i', 'am', 'to', 'seeing', 'you', 'every', 'day', '.', 'i', 'know', 'you', 'will', 'do', 'the', 'best', 'you', 'can', 'to', 'get', 'to', 'me', 'babe', '.', 'i', 'will', 'go', 'to', 'teach', 'my', 'class', 'at', 'your', 'midnight'] in text i can't believe how attached i am to seeing you every day. i know you will do the best you can to get to me babe. i will go to teach my class at your midnight
#
# Tokens ['just', 'sleeping', '..', 'and', 'surfing'] in text just sleeping..and surfing
#
# Tokens ['asked', '3mobile', 'if', '0870', 'chatlines', 'inclu', 'in', 'free', 'mins', '.', 'india', 'cust', 'servs', 'sed', 'yes', '.', 'l8er', 'got', 'mega', 'bill', '.', '3', 'dont', 'giv', 'a', 'shit', '.', 'bailiff', 'due', 'in', 'days', '.', 'i', 'o', '£250', '3', 'want', '£800'] in text asked 3mobile if 0870 chatlines inclu in free mins. india cust servs sed yes. l8er got mega bill. 3 dont giv a shit. bailiff due in days. i o £250 3 want £800
#
# Tokens ['yeah', 'it', "'s", 'jus', 'rite', '...'] in text yeah it's jus rite...
#
# Tokens ['armand', 'says', 'get', 'your', 'ass', 'over', 'to', 'epsilon'] in text armand says get your ass over to epsilon
#
# Tokens ['u', 'still', 'havent', 'got', 'urself', 'a', 'jacket', 'ah', '?'] in text u still havent got urself a jacket ah?
#
# Tokens ['i', "'m", 'taking', 'derek', '&', 'amp', ';', 'taylor', 'to', 'walmart', ',', 'if', 'i', "'m", 'not', 'back', 'by', 'the', 'time', 'you', "'re", 'done', 'just', 'leave', 'the', 'mouse', 'on', 'my', 'desk', 'and', 'i', "'ll", 'text', 'you', 'when', 'priscilla', "'s", 'ready'] in text i'm taking derek &amp; taylor to walmart, if i'm not back by the time you're done just leave the mouse on my desk and i'll text you when priscilla's ready
#
# Tokens ['hi', 'its', 'in', 'durban', 'are', 'you', 'still', 'on', 'this', 'number'] in text hi its in durban are you still on this number
#
# Tokens ['ic', '.', 'there', 'are', 'a', 'lotta', 'childporn', 'cars', 'then', '.'] in text ic. there are a lotta childporn cars then.
#
# Tokens ['had', 'your', 'contract', 'mobile', '11', 'mnths', '?', 'latest', 'motorola', ',', 'nokia', 'etc', '.', 'all', 'free', '!', 'double', 'mins', '&', 'text', 'on', 'orange', 'tariffs', '.', 'text', 'yes', 'for', 'callback', ',', 'no', 'to', 'remove', 'from', 'records', '.'] in text had your contract mobile 11 mnths? latest motorola, nokia etc. all free! double mins & text on orange tariffs. text yes for callback, no to remove from records.
#
# Tokens ['no', ',', 'i', 'was', 'trying', 'it', 'all', 'weekend', ';', 'v'] in text no, i was trying it all weekend ;v
#
# Tokens ['you', 'know', ',', 'wot', 'people', 'wear', '.', 't', 'shirts', ',', 'jumpers', ',', 'hat', ',', 'belt', ',', 'is', 'all', 'we', 'know', '.', 'we', 'r', 'at', 'cribbs'] in text you know, wot people wear. t shirts, jumpers, hat, belt, is all we know. we r at cribbs
#
# Tokens ['cool', ',', 'what', 'time', 'you', 'think', 'you', 'can', 'get', 'here', '?'] in text cool, what time you think you can get here?
#
# Tokens ['wen', 'did', 'you', 'get', 'so', 'spiritual', 'and', 'deep', '.', 'that', "'s", 'great'] in text wen did you get so spiritual and deep. that's great
#
# Tokens ['have', 'a', 'safe', 'trip', 'to', 'nigeria', '.', 'wish', 'you', 'happiness', 'and', 'very', 'soon', 'company', 'to', 'share', 'moments', 'with'] in text have a safe trip to nigeria. wish you happiness and very soon company to share moments with
#
# Tokens ['hahaha', '..', 'use', 'your', 'brain', 'dear'] in text hahaha..use your brain dear
#
# Tokens ['well', 'keep', 'in', 'mind', 'i', "'ve", 'only', 'got', 'enough', 'gas', 'for', 'one', 'more', 'round', 'trip', 'barring', 'a', 'sudden', 'influx', 'of', 'cash'] in text well keep in mind i've only got enough gas for one more round trip barring a sudden influx of cash
#
# Tokens ['yeh', '.', 'indians', 'was', 'nice', '.', 'tho', 'it', 'did', 'kane', 'me', 'off', 'a', 'bit', 'he', 'he', '.', 'we', 'shud', 'go', 'out', '4', 'a', 'drink', 'sometime', 'soon', '.', 'mite', 'hav', '2', 'go', '2', 'da', 'works', '4', 'a', 'laugh', 'soon', '.', 'love', 'pete', 'x', 'x'] in text yeh. indians was nice. tho it did kane me off a bit he he. we shud go out 4 a drink sometime soon. mite hav 2 go 2 da works 4 a laugh soon. love pete x x
#
# Tokens ['yes', 'i', 'have', '.', 'so', 'that', "'s", 'why', 'u', 'texted', '.', 'pshew', '...', 'missing', 'you', 'so', 'much'] in text yes i have. so that's why u texted. pshew...missing you so much
#
# Tokens ['no', '.', 'i', 'meant', 'the', 'calculation', 'is', 'the', 'same', '.', 'that', '&', 'lt', ';', '#', '&', 'gt', ';', 'units', 'at', '&', 'lt', ';', '#', '&', 'gt', ';', '.', 'this', 'school', 'is', 'really', 'expensive', '.', 'have', 'you', 'started', 'practicing', 'your', 'accent', '.', 'because', 'its', 'important', '.', 'and', 'have', 'you', 'decided', 'if', 'you', 'are', 'doing', '4years', 'of', 'dental', 'school', 'or', 'if', 'you', "'ll", 'just', 'do', 'the', 'nmde', 'exam', '.'] in text no. i meant the calculation is the same. that  &lt;#&gt; units at  &lt;#&gt; . this school is really expensive. have you started practicing your accent. because its important. and have you decided if you are doing 4years of dental school or if you'll just do the nmde exam.
#
# Tokens ['sorry', ',', 'i', "'ll", 'call', 'later'] in text sorry, i'll call later
#
# Tokens ['if', 'you', 'are', "n't", 'here', 'in', 'the', 'next', '&', 'lt', ';', '#', '&', 'gt', ';', 'hours', 'imma', 'flip', 'my', 'shit'] in text if you aren't here in the next  &lt;#&gt;  hours imma flip my shit
#
# Tokens ['anything', 'lor', '.', 'juz', 'both', 'of', 'us', 'lor', '.'] in text anything lor. juz both of us lor.
#
# Tokens ['get', 'me', 'out', 'of', 'this', 'dump', 'heap', '.', 'my', 'mom', 'decided', 'to', 'come', 'to', 'lowes', '.', 'boring', '.'] in text get me out of this dump heap. my mom decided to come to lowes. boring.
#
# Tokens ['ok', 'lor', '...', 'sony', 'ericsson', 'salesman', '...', 'i', 'ask', 'shuhui', 'then', 'she', 'say', 'quite', 'gd', '2', 'use', 'so', 'i', 'considering', '...'] in text ok lor... sony ericsson salesman... i ask shuhui then she say quite gd 2 use so i considering...
#
# Tokens ['ard', '6', 'like', 'dat', 'lor', '.'] in text ard 6 like dat lor.
#
# Tokens ['why', 'do', "n't", 'you', 'wait', "'til", 'at', 'least', 'wednesday', 'to', 'see', 'if', 'you', 'get', 'your', '.'] in text why don't you wait 'til at least wednesday to see if you get your .
#
# Tokens ['huh', 'y', 'lei', '...'] in text huh y lei...
#
# Tokens ['reminder', 'from', 'o2', ':', 'to', 'get', '2.50', 'pounds', 'free', 'call', 'credit', 'and', 'details', 'of', 'great', 'offers', 'pls', 'reply', '2', 'this', 'text', 'with', 'your', 'valid', 'name', ',', 'house', 'no', 'and', 'postcode'] in text reminder from o2: to get 2.50 pounds free call credit and details of great offers pls reply 2 this text with your valid name, house no and postcode
#
# Tokens ['this', 'is', 'the', '2nd', 'time', 'we', 'have', 'tried', '2', 'contact', 'u.', 'u', 'have', 'won', 'the', '£750', 'pound', 'prize', '.', '2', 'claim', 'is', 'easy', ',', 'call', '087187272008', 'now1', '!', 'only', '10p', 'per', 'minute', '.', 'bt-national-rate', '.'] in text this is the 2nd time we have tried 2 contact u. u have won the £750 pound prize. 2 claim is easy, call 087187272008 now1! only 10p per minute. bt-national-rate.
#
# Tokens ['will', 'ü', 'b', 'going', 'to', 'esplanade', 'fr', 'home', '?'] in text will ü b going to esplanade fr home?
#
# Tokens ['pity', ',', '*', 'was', 'in', 'mood', 'for', 'that', '.', 'so', '...', 'any', 'other', 'suggestions', '?'] in text pity, * was in mood for that. so...any other suggestions?
#
# Tokens ['the', 'guy', 'did', 'some', 'bitching', 'but', 'i', 'acted', 'like', 'i', "'d", 'be', 'interested', 'in', 'buying', 'something', 'else', 'next', 'week', 'and', 'he', 'gave', 'it', 'to', 'us', 'for', 'free'] in text the guy did some bitching but i acted like i'd be interested in buying something else next week and he gave it to us for free
#
# Tokens ['rofl', '.', 'its', 'true', 'to', 'its', 'name'] in text rofl. its true to its name

# %%
df['text'].replace("","")
# Out:
# 0         go
# 1         ok
# 2       free
# 3          u
# 4        nah
#         ...
# 5567
# 5568
# 5569    pity
# 5570
# 5571    rofl
# Name: text, Length: 5572, dtype: object

# %%
df.tail(10)
# Out:
#       label      text  word_l
# 5562      0        ok      96
# 5563      0       ard      19
# 5564      0                67
# 5565      0       huh      12
# 5566      1  reminder     147
# 5567      1               160
# 5568      0                36
# 5569      0      pity      57
# 5570      0               125
# 5571      0      rofl      26

# %% [markdown]
# Lemmatizing or Stemm function

# %% [markdown]
# Implementing text vectorization

# %% [markdown]
# It converts the raw text into a format the NLP model can understand and use. Vectorization will create a numerical representation of the text strings called a sparse matrix or word vectors. The model works with numbers and not raw text. We will use TfidfVectorizer to create the sparse matri

# %%
#Vectorization
tf_wb= TfidfVectorizer()

# %% [markdown]
# We then apply the initialized method to the text column so that it can transform the text strings into a sparse matrix.

# %%
X_tf = tf_wb.fit_transform(df['text'])

# %% [markdown]
# Converting the sparse matrix into an array

# %%
X_tf = X_tf.toarray()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-111-96dc4fcd564a> in <module>
# ----> 1 X_tf = X_tf.toarray()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'toarray'

# %% [markdown]
# Splitting the vectorized dataset

# %%
X_train_tf, X_test_tf, y_train_tf, y_test_tf = train_test_split(X_tf, df['label'].values, test_size=0.3)

# %% [markdown]
# After splitting the dataset, we will use the Counter module to check the number of data samples in the majority and minority classes. We import the module as follows:

# %%
from collections import Counter

# %%
Counter(y_train_tf)
# Out:
# Counter({0: 3355, 1: 545})

# %%
ROS = RandomOverSampler(sampling_strategy=1)
X_train_ros, y_train_ros = ROS.fit_resample(X_train_tf, y_train_tf)

# %%
Counter(y_train_ros)
# Out:
# Counter({0: 3355, 1: 3355})

# %% [markdown]
# Using the balanced dataset to build the same model

# %%
nb = GaussianNB()
nb.fit(X_train_tf, y_train_tf)
# Out:
# GaussianNB()

# %%
NB_pred= nb.predict(X_test_tf)
print(NB_pred)
# Out:
# [1 0 1 ... 1 1 1]

# %% [markdown]
# **Getting accuracy score of these predictions**

# %%
print(accuracy_score(y_test_tf, NB_pred))
# Out:
# 0.4072966507177033
